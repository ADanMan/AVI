# %% [markdown]
# # Notebook 5: Visualize for Paper
#
# **Objective**: Generate all figures and tables for publication

# %%
import sys
from pathlib import Path
import pandas as pd

sys.path.insert(0, str(Path.cwd().parent / 'src'))

from visualization.results_visualizer import ResultsVisualizer
from visualization.paper_tables import PaperTables

# %% [markdown]
# ## 1. Load Results

# %%
results_dir = Path('../data/results')
latest_exp = sorted(results_dir.glob('experiment_*'))[-1]
results_df = pd.read_csv(latest_exp / 'raw_results.csv')
print(f'✅ Loaded {len(results_df)} results')

# %% [markdown]
# ## 2. Generate Figures

# %%
viz = ResultsVisualizer(results_df, dpi=300)
print('🎨 Generating figures...\n')

# %% [markdown]
# ### Figure 1: Confusion Matrix

# %%
viz.plot_confusion_matrix(save_path='../paper/figures/fig1_confusion_matrix.png')

# %% [markdown]
# ### Figure 2: Latency Distribution

# %%
viz.plot_latency_distribution(save_path='../paper/figures/fig2_latency.png')

# %% [markdown]
# ### Figure 3: Quality Trade-off

# %%
viz.plot_helpfulness_vs_compliance(save_path='../paper/figures/fig3_quality.png')

# %% [markdown]
# ### Figure 4: Time-to-Compliance

# %%
viz.plot_time_to_compliance(save_path='../paper/figures/fig4_agility.png')

# %% [markdown]
# ## 3. Generate Tables

# %%
tables = PaperTables(results_df)
print('📊 Generating tables...\n')

# %%
perf_table = tables.generate_performance_table('../paper/tables/table1_performance.csv')

# %%
examples_table = tables.generate_qualitative_examples('../paper/tables/table2_examples.csv')

# %%
latency_table = tables.generate_latency_table('../paper/tables/table3_latency.csv')

# %% [markdown]
# ## Summary
#
# ✅ All visualizations generated!
#
# **Outputs**:
# - `paper/figures/` - 4 publication-ready figures (300 DPI)
# - `paper/tables/` - 3 tables (CSV → LaTeX)
#
# Ready for manuscript!
